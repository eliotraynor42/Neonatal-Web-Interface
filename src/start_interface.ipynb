# %%
# =================================== #
# Starts the web server. Simply start 
# apache and then run this code block 
# to interact with the website.
#
# To stop the server, stop this block
# and then click "restart" on the
# subsequent popup. Then close apache.
#
# By Eliot Raynor 12/05/25
# =================================== #

# %load_ext autoreload
# %autoreload 2
from bmes_ahmet_loader import *

#bmes.kaggle_downloaddataset('miadul/newborn-health-monitoring-dataset')
bmes.system([bmes.pythonexe(), 'app.py'])
# Out:
# Executing command: c:\Users\emrti\AppData\Local\Programs\Python\Python313\python.exe app.py
