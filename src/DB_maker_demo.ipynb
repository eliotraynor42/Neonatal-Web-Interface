# %% [markdown]
# # Test and Demo for DB_maker function

# %% [markdown]
# Function Goal:
# * Create a the NWI_DB database used for the project

# %%
from DB_maker import DB_maker
from bmes_ahmet_loader import *

import sqlite3 #Database Connection
# open a database connection
dbfile= bmes.userdownloaddir() + '/NWI_DB.db'; #Makes the files
conn = sqlite3.connect(dbfile); #Gets the DB connection
cur=conn.cursor()

# %%
data=conn.execute("SELECT * FROM patients;").fetchall()
print(data)
# Out:
# []
