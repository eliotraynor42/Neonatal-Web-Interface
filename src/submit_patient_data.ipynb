# %% [markdown]
# # Test and Demo for submit_patient_data

# %% [markdown]
# ## Setup

# %%
from submit_patient_data import submit_patient_data
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[1], line 4
#       1 from submit_patient_data import submit_patient_data
#       2 from DB_maker import DB_maker
# ----> 4 DB_maker()
#       6 import sqlite3 #Database Connection
#       7 dbfile= bmes.userdownloaddir() + '/NWI_DB.db'; #Path
#
# File c:\Users\alexa\OneDrive\Documents\GitHub\Neonatal-Web-Interface\src\DB_maker.py:56, in DB_maker()
#      53 messages=["She has spit up 3 times today. Is that normal?","She cried today, should I be worried about collic?","She has a rash on her leg, should I bring her in?"]
#      55 #==========Clean Slate==========#
# ---> 56 conn.execute('DROP TABLE IF EXISTS patients;')
#      57 conn.execute('DROP TABLE IF EXISTS patient_visit_data;')
#      58 conn.execute('DROP TABLE IF EXISTS doctors;')
#
# OperationalError: database is locked

# %% [markdown]
# ## Cases

# %% [markdown]
# ### Case 1: All data within the normal ranges, no warning should be created

# %%
user_input=[100,10,53,12,37.9,150,45,90,10,8,5]
reference = ['weight_kg', 'length_cm', 'head_circumference_cm', 'temperature_c', 'heart_rate_bpm', 
                    'respiratory_rate_bpm', 'oxygen_saturation', 'feeding_frequency_per_day', 
                    'urination_count_per_day', 'stool_count_per_day']
    
warning=submit_patient_data(user_input)
print(warning)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[18], line 6
#       1 user_input=[100,10,53,12,37.9,150,45,90,10,8,5]
#       2 reference = ['weight_kg', 'length_cm', 'head_circumference_cm', 'temperature_c', 'heart_rate_bpm',
#       3                     'respiratory_rate_bpm', 'oxygen_saturation', 'feeding_frequency_per_day',
#       4                     'urination_count_per_day', 'stool_count_per_day']
# ----> 6 warning=submit_patient_data(user_input)
#       7 print(warning)
#       9 data=conn.execute("SELECT * FROM patient_visit_data WHERE id=100"),fetch(all)
#
# File c:\Users\alexa\OneDrive\Documents\GitHub\Neonatal-Web-Interface\src\submit_patient_data.py:47, in submit_patient_data(user_input)
#      43             if vals[i+1]<normal_ranges[i-3][0] or normal_ranges[i-3][1]<vals[i+1]: #Will run this for everything after
#      44                 warnings=("Inputted Data is outside the normal range, please contact your doctor.")
# ---> 47 data=conn.execute(f"SELECT * FROM patients WHERE patients.id={vals[0]};").fetchone()
#      50 #Gets the new age in days
#      51 birthdate=datetime.date.fromisoformat(data[5]) #Takes the birth date and turns from text into a format a date object
#
# OperationalError: database is locked
