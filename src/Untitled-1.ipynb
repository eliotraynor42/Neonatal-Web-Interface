# %%
# %load_ext autoreload
# %autoreload 2
# import sys,os; sys.path.append(os.environ['BMESAHMETDIR']); import bmes  #see bmes.ahmet/README.txt for details and alternative ways to import bmes.
from bmes_ahmet_loader import *

#bmes.kaggle_downloaddataset('miadul/newborn-health-monitoring-dataset')
bmes.system([bmes.pythonexe(), 'app.py'])
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Executing command: c:\Users\emrti\AppData\Local\Programs\Python\Python313\python.exe app.py
