# %% [markdown]
# Test And Demo for fucntion get_data

# %% [markdown]
# Function Description:
# * Takes in a patient's id and outputs their latest health data
# * Not possible to call for rows outside the range

# %%
from get_data import get_data

# %% [markdown]
# Test Case 1: ID is 4

# %%
user_id=4
patients=get_data(user_id)
print(patients)
# Out:
# [{'ID': 4, 'Age': 94, 'Weight': 10.103441265620628, 'Length': 60.88184571427591, 'Head_Circumference': 42.78534905296418, 'Temperature': 37.43, 'Heart_Rate': 130, 'Respiratory_Rate': 45, 'Oxygen_Saturation': 89, 'Primary_Feeding_Type': 'Mixed', 'Feeding_Per_Day': 8, 'Urination_Per_Day': 9, 'Stool_Per_Day': 7, 'Immunizations_Needed': 'Yes', 'Reflexes': 'No', 'Risk': 'Healthy'}]

# %% [markdown]
# Test Case 2: ID is 100

# %%
user_id2=100
patients2=get_data(user_id2)
print(patients2)
# Out:
# [{'ID': 100, 'Age': 98, 'Weight': 11.806328534191644, 'Length': 55.466357549938294, 'Head_Circumference': 42.24628683171174, 'Temperature': 37.04, 'Heart_Rate': 140, 'Respiratory_Rate': 38, 'Oxygen_Saturation': 92, 'Primary_Feeding_Type': 'Formula', 'Feeding_Per_Day': 9, 'Urination_Per_Day': 7, 'Stool_Per_Day': 7, 'Immunizations_Needed': 'No', 'Reflexes': 'Yes', 'Risk': 'Under Watch'}]
