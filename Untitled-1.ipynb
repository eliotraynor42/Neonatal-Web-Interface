# %%
# %load_ext autoreload
# %autoreload 2
# import sys,os; sys.path.append(os.environ['BMESAHMETDIR']); import bmes  #see bmes.ahmet/README.txt for details and alternative ways to import bmes.
from bmes_ahmet_loader import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 get_ipython().run_line_magic('autoreload', '2')
#       3 # import sys,os; sys.path.append(os.environ['BMESAHMETDIR']); import bmes  #see bmes.ahmet/README.txt for details and alternative ways to import bmes.
# ----> 4 from bmes_ahmet_loader import *
#
# ModuleNotFoundError: No module named 'bmes_ahmet_loader'
